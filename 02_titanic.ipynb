# %%
import pandas as pd
import matplotlib.pyplot as plt
#titanic=pd.read_csv("")

# %% [markdown]
# #Titanic Tabulation
#
# The Titanic was a ship that would transport over a thousand people to New York that was until the unfortunate collision with an ice berg that would cause the ship to sink. Fortunately some people would survive and the sinking caused a change in the way ships were produced allowing people nowadays to travel more safely. This change was brought about the analyzing of information of the Titanic which I also had a few questions about.

# %%
titanic_df = pd.read_csv("titanic_passengers (1).csv")

# %% [markdown]
# How many passengers were under the 5?

# %%
age = titanic_df["Age"]
age.plot.hist(edgecolor = 'pink')
plt.title('Passengers Under 5')
plt.xlabel('Ages under 5')
plt.ylabel('Number of Passengers')
# Out:
# Text(0, 0.5, 'Number of Passengers')

# %% [markdown]
#    How many passengers were in first class?

# %% [markdown]
#  Did gender have anything to do with survival rate?

# %% [markdown]
#  Did the price increase with class size?

# %% [markdown]
#  Does the amount that the passengers paid along with their class affect their survival rate?
